# %% [markdown]
# # Electronics Retail Company Dataset
#
# Генерация датасета на тему Electronics Retail Company, для последующего анализа и построения модели машинного обучения.
#
# Структура создаваемого датасета:
#
# 1. **OrderID** – *int* – ID заказа, уникален, AUTO_INCREMENT
# 2. **Product** – *nvarchar(50)* – название электронного компонента, NOT NULL
# 3. **ProductCategory** – *nvarchar(50)* – категория электронного компонента, NOT NULL
# 4. **Brand** – *nvarchar(50)* – производитель электронного компонента, NULL
# 5. **Description** – *nvarchar(256)* – краткое описание электронного компонента, NULL
# 6. **StandardCost** – *money* – себестоимость электронного компонента, NOT NULL
# 7. **UnitPrice** – *money* – стоимость на продажу электронного компонента, NOT NULL
# 8. **DateRequest** – *datetime* – дата и время заказа, в пределах будних дней с 9:00 по 18:00 с 01.04.2024 по 31.03.2025, NULL
# 9. **QuantitySold** – *int* – количество проданных электронных компонентов за заказ, NOT NULL
# 10. **DiscountPrice** – *decimal(3, 2)* – скидка на электронный компонент, зависящая от количества на продажу, NOT NULL
# 11. **TotalPrice** – *money* – общая цена за заказ с учетом количества и скидки, NOT NULL
# 12. **CustomerName** – *nvarchar(50)* – ФИО покупателя, NOT NULL
# 13. **CustomerRegion** – *nvarchar(50)* – регионы Беларуси (всего 6 областей + столица Минск), NOT NULL
# 14. **CustomerCity** – *nvarchar(50)* – города принадлежащие областям, также + Минск, NOT NULL
# 15. **Canceled** – *bit* – отказ или возврат электронного компонента, NOT NULL
# 16. **Feedback** – *tinyint* – отзыв об электронном компоненте, оценка от 1 до 5, NULL
#
# Датасет в формате *csv*. Количество строк - 5000. Все данные фиктивные.

# %%
# Импорт библиотек
import random
import string
import statistics
import csv
import datetime
import faker
import os

# %%
# -----------------------
# ПРОВЕРКА И УДАЛЕНИЕ ФАЙЛА ПЕРЕД СОЗДАНИЕМ
# -----------------------

# Имя файла
csv_file = r'D:\\Dataset\electronics_retail_dataset.csv'

# Проверяем, существует ли файл
if os.path.exists(csv_file):
    os.remove(csv_file)  # Удаляем файл
    print(f"Файл {csv_file} удалён.")
# Out:
# Файл D:\\Dataset\electronics_retail_dataset.csv удалён.

# %%
# -----------------------
# НАСТРОЙКА НАБОРОВ ПРОДУКТОВ
# -----------------------

# Устанавливаем фиксированный seed
SEED = 42
random.seed(SEED)

# Количество создаваемых продуктов
NUM_PRODUCTS = 100

# Список категорий
categories = [
    "Микросхема", "Оптопара", "Конденсатор", "Резистор", 
    "Индуктивность", "Предохранитель", "Диод", "Транзистор", "Резонатор",
    "Трансформатор", "Датчик", "Акустика", "Светодиод", "Дисплей",
    "Реле", "Разъем", "Переключатель", "Аккумулятор"
]

# Список наименований брендов
full_nouns = [
    "Arkham Devices", "Sumeru Instruments", "Digit Solutions", 
    "Quantum Systems", "Nexus Labs", "Fusion Technologies", "JPZ"
]

adjectives = ["Kepler", "Arion", "Delphini"]
nouns = ["Instruments", "Systems", "Technologies"]

# Список коротких слов
words = ["быстрый", "надёжный", "новый", "простой", "удобный", "точный", "сверхмощный", "легкий"]

# Список цен себестоимости
costs = [
    37.0, 2.65, 0.15, 0.14, 0.43, 0.36, 0.36, 0.60, 5.80, 
    26.0, 8.10, 1.10, 0.29, 18.0, 6.90, 5.60, 2.90, 20.50
]

# Вычисление среднего и стандартного отклонения себестоимости
stats = {"mean": statistics.mean(costs), "std": statistics.stdev(costs)}

# Минимальная и максимальная надбавка к себестоимости
MIN_MARKUP, MAX_MARKUP = 1.5, 2.0

# Функция для генерации парт-номеров с фиксированным форматом (9 символов)
def generate_part_number():
    part_number = ''.join(random.choices(string.ascii_uppercase + string.digits, k=9))
    return part_number

# Функция для генерации случайных категорий под парт-номера
def generate_category():
    return f"{random.choice(categories)}"

# Функция для генерации случайных названий брендов
def generate_brand():
    # Генерация полного названия бренда с 60% вероятности
    if random.random() > 0.4:
        return f"{random.choice(full_nouns)}"
    # Генерация объединенного названия бренда с 30% вероятности
    elif random.random() < 0.3:
        return f"{random.choice(adjectives)} {random.choice(nouns)}"
    # Бренд не указан (10%)
    else:
        return None

# Функция для генерации случайного описания (6 слов + 2 числа)
def generate_description():
    # Генерация описания с 90% вероятности
    if random.random() > 0.4:
        selected_words = random.sample(words, 6)  # Выбираем случайные 6 слов
        numbers = [str(random.randint(1, 999)), str(random.randint(1, 999))]  # Генерируем 2 числа
        elements = selected_words + numbers  # Объединяем слова и числа
        random.shuffle(elements)  # Перемешиваем порядок
        return " ".join(elements)
    # Описание не указано (10%)
    else:
        return None

# Функция для генерации себестоимости по нормальному распределению
def generate_cost():
    while True:
        value = round(random.gauss(stats["mean"], stats["std"]), 2)
        if value > 0:  # Проверяем, что значение положительное
            return value

# Функция для генерации цены на продажу на основе себестоимости
def generate_unit_prices(st_costs: iter):
    ut_prices = []
    for cost in st_costs:
        up_min, up_max = cost * MIN_MARKUP, cost * MAX_MARKUP
        ut_prices.append(round(random.uniform(up_min, up_max), 2))
    return ut_prices

# %%
# -----------------------
# ГЕНЕРАЦИЯ НАБОРОВ ПРОДУКТОВ
# -----------------------

# Пример генерации нескольких парт-номеров
PRODUCT_CODES = [generate_part_number() for _ in range(NUM_PRODUCTS)]

# Пример генерации нескольких категорий
PRODUCT_CATEGORIES = [generate_category() for _ in range(NUM_PRODUCTS)]

# Пример генерации нескольких брендов
BRANDS = [generate_brand() for _ in range(NUM_PRODUCTS)]

# Пример генерации нескольких описаний
DESCRIPTIONS = [generate_description() for _ in range(NUM_PRODUCTS)]

# Пример генерации нескольких цен себестоимости
STANDARD_COSTS = [generate_cost() for _ in range(NUM_PRODUCTS)]

# Пример генерации нескольких цен на продажу
UNIT_PRICES = generate_unit_prices(STANDARD_COSTS)

PRODUCTS_INFO = {
    "products": PRODUCT_CODES,
    "categories": PRODUCT_CATEGORIES,
    "brands": BRANDS,
    "descriptions": DESCRIPTIONS,
    "standard_costs": STANDARD_COSTS,
    "unit_prices": UNIT_PRICES
}

PRODUCTS_INFO
# Out:
# {'products': ['XAJI0Y6DP',
#   'BHSAHXTHV',
#   '3A3ZMF8MD',
#   'D4V30T9NT',
#   '3W5UZBIKC',
#   'IDKWNNHJ7',
#   'XVG0FN9XU',
#   'Y41IBLJH7',
#   '5LXO6QJIU',
#   'JV6OH9SDB',
#   'DW2PCN9T8',
#   '4AZYTJXEP',
#   'Q85JSG65K',
#   'XVF1T2TAL',
#   'A753LC58D',
#   'RC11ERTJ5',
#   'PHT0HL9XP',
#   'SEIMVIHCW',
#   'I64CIYHE7',
#   'UR23GDPPQ',
#   '0Y9DOM5IG',
#   'QPKI7P5TB',
#   '94874FRHO',
#   'CN9J2QP89',
#   'UZFK8UT0C',
#   'VS4F8CGVY',
#   'IE6IVWPVS',
#   '7HZIOYKL1',
#   'CQ99CHJ75',
#   '5NF4ZW9XA',
#   '3KX7EEDTJ',
#   'VZHWJR64D',
#   'PJA1WJ0TP',
#   'AC56T4UFE',
#   'L6246HID2',
#   '5OWF75935',
#   'A0L7253J2',
#   'D54I3QK2I',
#   'AGL58KXO9',
#   'T7E8G8JDP',
#   '0LVSNUJZA',
#   '7TZ0YNCXL',
#   'L4ZKLOOKE',
#   'P7Y6WKTAK',
#   'PUXQPHR62',
#   'GDSWM31YI',
#   'HAIR4COWG',
#   'ZRIXA11DP',
#   'G8SBI4Q2Y',
#   '9V86WZS3T',
#   '60RJIW1SW',
#   'JCKJLTEIY',
#   'ZCOTOHP6V',
#   'Z41NAM148',
#   'P0TVHHPBM',
#   'YOFQEWAOU',
#   'AXEQBNHL1',
#   'N13JCAT9M',
#   'X2X18HAFE',
#   'YUHZ1GV0E',
#   '38DALY8OZ',
#   'CYWD14VE9',
#   '2MPNSM43D',
#   '8W3ZP08J3',
#   'TRP0J43D5',
#   'IQVNB4GH2',
#   'M5ZJA8DZR',
#   '1YXR2DHYL',
#   'URTP0LZJJ',
#   'EGET1GHR0',
#   '9SKDGIGAT',
#   'J9TZE5R5U',
#   'QPGB7R3OC',
#   'WBFUK9E1V',
#   '2ISQP49KW',
#   'V08HHXFGC',
#   'AQVKIZZQY',
#   '72WX7PTX6',
#   '3CFL0UKEY',
#   'Z7SRCBPLJ',
#   'D84U89YJB',
#   '1QX6GVWRD',
#   'MLY4LYK83',
#   'TQLL8OS9X',
#   'TOGN1W1HT',
#   '7PZE9VIFT',
#   'TD96QE3RZ',
#   'SJ49ITN7S',
#   '55J2O7S3K',
#   'KV9RFTMTT',
#   'QLGZUI1B0',
#   'Z3NX39RBS',
#   'V55PSQ0OX',
#   'FQ8MYX444',
#   'NLZ15BCW7',
#   '90PDW5PY6',
#   'B2KNFTU2G',
#   'C5WI6FQJJ',
#   'A26YFPMVX',
#   'PJ4HNRIUU'],
#  'categories': ['Трансформатор',
#   'Микросхема',
#   'Светодиод',
#   'Резонатор',
#   'Микросхема',
#   'Оптопара',
#   'Разъем',
#   'Трансформатор',
#   'Транзистор',
#   'Акустика',
#   'Транзистор',
#   'Диод',
#   'Резонатор',
#   'Индуктивность',
#   'Резистор',
#   'Оптопара',
#   'Трансформатор',
#   'Реле',
#   'Оптопара',
#   'Акустика',
#   'Индуктивность',
#   'Конденсатор',
#   'Трансформатор',
#   'Датчик',
#   'Дисплей',
#   'Предохранитель',
#   'Диод',
#   'Индуктивность',
#   'Аккумулятор',
#   'Акустика',
#   'Переключатель',
#   'Переключатель',
#   'Резонатор',
#   'Предохранитель',
#   'Резонатор',
#   'Разъем',
#   'Трансформатор',
#   'Датчик',
#   'Резистор',
#   'Реле',
#   'Конденсатор',
#   'Индуктивность',
#   'Транзистор',
#   'Светодиод',
#   'Аккумулятор',
#   'Акустика',
#   'Конденсатор',
#   'Светодиод',
#   'Микросхема',
#   'Резонатор',
#   'Аккумулятор',
#   'Резистор',
#   'Реле',
#   'Акустика',
#   'Резонатор',
#   'Светодиод',
#   'Акустика',
#   'Резистор',
#   'Транзистор',
#   'Разъем',
#   'Микросхема',
#   'Аккумулятор',
#   'Датчик',
#   'Транзистор',
#   'Конденсатор',
#   'Реле',
#   'Трансформатор',
#   'Дисплей',
#   'Резистор',
#   'Индуктивность',
#   'Оптопара',
#   'Оптопара',
#   'Трансформатор',
#   'Разъем',
#   'Резистор',
#   'Резистор',
#   'Транзистор',
#   'Аккумулятор',
#   'Индуктивность',
#   'Светодиод',
#   'Реле',
#   'Акустика',
#   'Аккумулятор',
#   'Дисплей',
#   'Индуктивность',
#   'Дисплей',
#   'Резистор',
#   'Разъем',
#   'Дисплей',
#   'Резонатор',
#   'Оптопара',
#   'Акустика',
#   'Диод',
#   'Реле',
#   'Реле',
#   'Транзистор',
#   'Акустика',
#   'Резистор',
#   'Акустика',
#   'Аккумулятор'],
#  'brands': ['Fusion Technologies',
#   None,
#   'Arion Instruments',
#   'Fusion Technologies',
#   'Arkham Devices',
#   None,
#   'JPZ',
#   'Arkham Devices',
#   'Nexus Labs',
#   'Kepler Systems',
#   'JPZ',
#   'Arkham Devices',
#   None,
#   'Nexus Labs',
#   'Delphini Instruments',
#   None,
#   'Nexus Labs',
#   'Kepler Instruments',
#   'Nexus Labs',
#   'Arion Systems',
#   'Arkham Devices',
#   'Sumeru Instruments',
#   'Arkham Devices',
#   'JPZ',
#   'Digit Solutions',
#   'Arkham Devices',
#   None,
#   'Fusion Technologies',
#   None,
#   'Arkham Devices',
#   'Kepler Systems',
#   'Nexus Labs',
#   'Digit Solutions',
#   None,
#   None,
#   'JPZ',
#   'JPZ',
#   'JPZ',
#   'JPZ',
#   None,
#   None,
#   'Quantum Systems',
#   'Digit Solutions',
#   'Fusion Technologies',
#   None,
#   'Quantum Systems',
#   None,
#   'Delphini Systems',
#   'Nexus Labs',
#   None,
#   'Fusion Technologies',
#   None,
#   'JPZ',
#   'Fusion Technologies',
#   'Arion Systems',
#   None,
#   None,
#   'Digit Solutions',
#   'Digit Solutions',
#   'Kepler Systems',
#   'JPZ',
#   'Nexus Labs',
#   'Nexus Labs',
#   None,
#   'Digit Solutions',
#   'Arion Systems',
#   'Kepler Technologies',
#   'Arkham Devices',
#   None,
#   None,
#   None,
#   None,
#   'JPZ',
#   'Nexus Labs',
#   'Kepler Technologies',
#   'Arion Technologies',
#   'Nexus Labs',
#   'Digit Solutions',
#   None,
#   'Delphini Technologies',
#   'Nexus Labs',
#   'Arkham Devices',
#   None,
#   'Kepler Instruments',
#   'Digit Solutions',
#   'Delphini Systems',
#   None,
#   'Nexus Labs',
#   'Fusion Technologies',
#   'Arkham Devices',
#   None,
#   'Quantum Systems',
#   'JPZ',
#   None,
#   'Fusion Technologies',
#   'Arkham Devices',
#   'Digit Solutions',
#   None,
#   'Fusion Technologies',
#   'Arkham Devices'],
#  'descriptions': ['406 удобный надёжный 81 легкий простой новый точный',
#   'новый легкий точный 982 745 надёжный удобный сверхмощный',
#   'надёжный легкий простой точный 779 удобный новый 594',
#   None,
#   None,
#   'надёжный новый сверхмощный 76 удобный 520 легкий быстрый',
#   None,
#   '568 легкий 595 сверхмощный удобный простой точный надёжный',
#   '662 177 легкий точный новый удобный простой быстрый',
#   None,
#   'точный 663 343 удобный быстрый сверхмощный новый простой',
#   'простой 991 удобный быстрый новый надёжный легкий 318',
#   'быстрый удобный 687 сверхмощный 434 надёжный точный новый',
#   'точный 865 сверхмощный легкий быстрый 303 удобный надёжный',
#   '710 сверхмощный удобный 852 новый надёжный быстрый простой',
#   'удобный надёжный новый простой точный сверхмощный 245 317',
#   'надёжный удобный простой сверхмощный точный легкий 54 657',
#   None,
#   'сверхмощный быстрый простой удобный легкий 933 970 надёжный',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '940 точный надёжный быстрый легкий сверхмощный удобный 850',
#   'простой 795 296 новый легкий быстрый надёжный точный',
#   None,
#   '299 быстрый новый удобный сверхмощный надёжный легкий 148',
#   None,
#   'быстрый 482 895 сверхмощный удобный легкий надёжный точный',
#   None,
#   None,
#   None,
#   'надёжный легкий удобный новый сверхмощный 560 361 быстрый',
#   '207 быстрый сверхмощный 45 надёжный точный новый простой',
#   None,
#   'сверхмощный простой новый точный 819 128 быстрый надёжный',
#   'сверхмощный легкий точный удобный 81 новый быстрый 435',
#   None,
#   'надёжный 455 простой сверхмощный легкий новый удобный 360',
#   None,
#   'быстрый надёжный легкий простой 870 удобный точный 623',
#   None,
#   'быстрый простой точный надёжный 455 782 новый удобный',
#   'простой легкий новый 936 надёжный 397 сверхмощный быстрый',
#   'надёжный 177 сверхмощный точный быстрый удобный легкий 921',
#   'надёжный сверхмощный удобный 125 простой новый 230 точный',
#   'удобный простой 317 точный сверхмощный надёжный быстрый 408',
#   'быстрый 849 новый легкий удобный простой 900 точный',
#   None,
#   None,
#   '202 сверхмощный 651 простой удобный надёжный новый быстрый',
#   'надёжный простой удобный точный легкий 43 846 новый',
#   '297 сверхмощный новый точный 559 удобный быстрый простой',
#   'точный новый простой удобный 349 быстрый 622 сверхмощный',
#   'точный новый быстрый простой 254 461 надёжный легкий',
#   None,
#   '782 новый сверхмощный легкий быстрый удобный точный 164',
#   None,
#   None,
#   '289 новый надёжный легкий простой быстрый удобный 507',
#   '584 надёжный сверхмощный точный 53 быстрый простой новый',
#   'сверхмощный точный удобный простой быстрый 100 легкий 999',
#   'сверхмощный быстрый простой 731 удобный точный легкий 342',
#   None,
#   'легкий точный сверхмощный простой новый удобный 577 307',
#   'точный сверхмощный 991 672 простой удобный надёжный быстрый',
#   None,
#   'быстрый надёжный точный сверхмощный 322 легкий удобный 452',
#   'быстрый 333 новый точный надёжный удобный сверхмощный 679',
#   'удобный точный сверхмощный 306 легкий 572 простой надёжный',
#   None,
#   'легкий простой новый надёжный 839 удобный 354 быстрый',
#   'удобный 279 713 надёжный простой новый легкий сверхмощный',
#   'удобный быстрый надёжный 339 точный сверхмощный простой 735',
#   'надёжный удобный точный простой новый 662 293 легкий',
#   'быстрый 960 простой точный надёжный 191 новый сверхмощный',
#   '829 легкий новый удобный простой 116 надёжный быстрый',
#   None,
#   None,
#   None,
#   '89 удобный легкий точный надёжный простой новый 336',
#   'надёжный простой новый быстрый 977 удобный 338 точный',
#   'точный 416 простой 703 легкий быстрый сверхмощный новый',
#   None,
#   None,
#   None,
#   '681 новый легкий точный сверхмощный простой 822 удобный',
#   'точный удобный 518 новый быстрый 925 легкий сверхмощный',
#   None,
#   None,
#   'сверхмощный удобный простой быстрый 526 надёжный точный 426',
#   'быстрый 353 434 надёжный простой сверхмощный точный новый',
#   'надёжный 891 точный сверхмощный легкий новый простой 460',
#   None,
#   'сверхмощный надёжный простой 475 удобный точный быстрый 306',
#   None,
#   None],
#  'standard_costs': [20.5,
#   23.0,
#   10.76,
#   13.69,
#   2.51,
#   20.7,
#   13.5,
#   12.88,
#   13.17,
#   1.84,
#   18.66,
#   10.76,
#   3.17,
#   8.56,
#   1.81,
#   15.41,
#   7.28,
#   19.73,
#   0.58,
#   10.88,
#   0.46,
#   29.82,
#   6.13,
#   5.46,
#   21.08,
#   14.91,
#   21.97,
#   4.49,
#   6.47,
#   20.34,
#   16.46,
#   3.98,
#   5.5,
#   14.09,
#   5.73,
#   10.86,
#   28.46,
#   14.95,
#   17.0,
#   17.92,
#   11.51,
#   14.19,
#   1.33,
#   12.9,
#   5.51,
#   11.4,
#   10.8,
#   3.14,
#   17.47,
#   10.92,
#   5.2,
#   5.74,
#   24.94,
#   16.14,
#   9.11,
#   14.77,
#   15.19,
#   2.59,
#   13.81,
#   3.61,
#   14.08,
#   23.96,
#   7.25,
#   21.77,
#   4.53,
#   8.24,
#   17.0,
#   5.13,
#   19.33,
#   2.15,
#   0.22,
#   24.7,
#   11.69,
#   4.48,
#   4.53,
#   14.12,
#   6.34,
#   10.62,
#   19.16,
#   21.11,
#   8.99,
#   5.62,
#   14.39,
#   9.34,
#   21.38,
#   7.97,
#   21.13,
#   16.7,
#   4.23,
#   8.64,
#   4.7,
#   11.84,
#   4.09,
#   12.31,
#   1.07,
#   5.64,
#   32.62,
#   20.17,
#   4.15,
#   9.84],
#  'unit_prices': [39.13,
#   35.06,
#   16.17,
#   21.48,
#   4.56,
#   31.75,
#   21.27,
#   20.73,
#   22.76,
#   2.82,
#   33.94,
#   21.16,
#   6.2,
#   15.66,
#   2.73,
#   27.22,
#   12.42,
#   29.76,
#   1.08,
#   19.23,
#   0.76,
#   52.22,
#   11.33,
#   9.37,
#   41.52,
#   23.7,
#   43.04,
#   7.91,
#   10.48,
#   36.81,
#   26.77,
#   6.68,
#   10.44,
#   21.69,
#   11.34,
#   18.78,
#   46.15,
#   27.64,
#   28.05,
#   34.3,
#   17.73,
#   28.32,
#   2.43,
#   19.55,
#   9.38,
#   19.25,
#   18.77,
#   5.71,
#   32.34,
#   16.83,
#   10.0,
#   10.46,
#   41.54,
#   32.1,
#   18.1,
#   28.76,
#   29.77,
#   4.18,
#   26.94,
#   6.66,
#   25.11,
#   39.19,
#   14.23,
#   40.11,
#   7.43,
#   14.6,
#   31.09,
#   8.16,
#   37.21,
#   3.24,
#   0.35,
#   38.83,
#   22.33,
#   8.56,
#   8.9,
#   23.29,
#   11.3,
#   18.94,
#   36.88,
#   38.81,
#   15.91,
#   9.51,
#   26.91,
#   17.7,
#   39.44,
#   12.27,
#   39.57,
#   27.94,
#   6.55,
#   13.96,
#   7.23,
#   21.34,
#   7.39,
#   22.13,
#   2.12,
#   9.38,
#   59.27,
#   38.16,
#   7.16,
#   15.88]}

# %%
# -----------------------
# НАСТРОЙКА И ГЕНЕРАЦИЯ НАБОРОВ ПОКУПАТЕЛЕЙ
# -----------------------

# Количество создаваемых покупателей
NUM_CUSTOMERS = 100

# Инициализация объекта Faker с русской локализацией
fake = faker.Faker(["ru_RU"])

# Генерация списка ФИО с помощью объекта fake
NAMES = [fake.last_name() + ' ' + fake.first_name() + ' ' + fake.middle_name() for _ in range(NUM_CUSTOMERS)]

# Список регионов РБ
regions = [
    "Брестская область", "Витебская область", 
    "Гомельская область", "Гродненская область", 
    "Могилёвская область", "Минская область",
    "Минск"
]

# Словарь - регион: список городов (может содержать разные наименования для того же города)
region_cities = {
    "Брестская область": ["Брест", "Барановичи", "Берёза", "Пинск"],
    "Витебская область": ["Витебск", "Полоцк", "Новополоцк", "Орша"],
    "Гомельская область": ["Гомель", "Мозырь", "Жлобин", "Речица"],
    "Гродненская область": ["Гродно", "Лида", "Слоним", "Волковыск"],
    "Могилёвская область": ["Могилёв", "Бобруйск", "Горки", "Осиповичи"],
    "Минская область": ["Молодечно", "Борисов", "Жодино", "Слуцк"],
    "Минск": ["Минск"]
}

# Функция для генерации региона/города
def generate_region_city():
    region = random.choice(regions)
    city = random.choice(region_cities[region])
    return region, city

# Генерация списка пар регион - город
CUSTOMER_WHEREABOUTS = [generate_region_city() for _ in range(NUM_CUSTOMERS)]

# Распаковываем список пар регион - город
CUSTOMER_REGIONS, CUSTOMER_CITIES = zip(*CUSTOMER_WHEREABOUTS)

CUSTOMERS_INFO = {
    "names": NAMES,
    "regions": CUSTOMER_REGIONS,
    "cities": CUSTOMER_CITIES
}

CUSTOMERS_INFO
# Out:
# {'names': ['Субботина Аркадий Игнатьевич',
#   'Рябова Вероника Ивановна',
#   'Орехов Амос Фокич',
#   'Логинова Евстигней Гордеевич',
#   'Шаров Виссарион Трифонович',
#   'Пестова Евсей Даниловна',
#   'Медведева Афиноген Венедиктович',
#   'Константинова Станимир Захаровна',
#   'Дмитриев Прокл Николаевна',
#   'Ильина Лонгин Альбертовна',
#   'Марков Ким Феоктистович',
#   'Ковалев Лавр Харлампьевич',
#   'Юдин Будимир Робертовна',
#   'Киселев Модест Ярославович',
#   'Гаврилов Остромир Дорофеевич',
#   'Зуева Илья Демьянович',
#   'Коновалов Наина Артемьевич',
#   'Филиппов Натан Вениаминовна',
#   'Нестеров Терентий Вячеславовна',
#   'Шаров Болеслав Романовна',
#   'Симонова Симон Макаровна',
#   'Белозерова Вячеслав Филипповна',
#   'Тетерина Парамон Федосьевич',
#   'Белова Аполлон Адамович',
#   'Горбачева Адам Евсеевич',
#   'Архипова Мариан Абрамович',
#   'Шаров Герасим Вадимовна',
#   'Самсонова Онуфрий Тимофеевна',
#   'Никитин Андрей Ефимовна',
#   'Игнатьев Антип Болеславовна',
#   'Трофимова Анна Федосеевич',
#   'Колесникова Аверкий Игнатьевич',
#   'Назарова Феврония Геннадьевна',
#   'Ларионов Терентий Андреевич',
#   'Пахомов Константин Викторовна',
#   'Савин Рубен Святославовна',
#   'Дьячков Ладислав Дмитриевна',
#   'Галкина Конон Харлампович',
#   'Муравьев Прасковья Германович',
#   'Наумов Панкрат Константиновна',
#   'Гришина Флорентин Ааронович',
#   'Суворова Виссарион Никифоровна',
#   'Ларионов Иван Игоревич',
#   'Тарасов Гордей Ефстафьевич',
#   'Рожкова Аркадий Чеславович',
#   'Колобов Твердислав Павловна',
#   'Зиновьева Владислав Тихонович',
#   'Овчинников Нонна Артурович',
#   'Игнатова Роман Зиновьевич',
#   'Мельникова Владлен Даниилович',
#   'Галкина Дмитрий Игнатьевич',
#   'Тетерина Герасим Григорьевна',
#   'Бобылева Наина Мироновна',
#   'Назаров Аким Павловна',
#   'Силина Конон Феоктистович',
#   'Петухова Нифонт Ярославович',
#   'Журавлева Твердислав Витальевич',
#   'Евдокимова Эммануил Артемовна',
#   'Красильников Евстафий Вилорович',
#   'Поляков Ия Андреевна',
#   'Игнатова Азарий Георгиевич',
#   'Соболев Андрей Эльдаровна',
#   'Панфилова Артемий Брониславович',
#   'Селезнев Владимир Павловна',
#   'Попов Ювеналий Елизарович',
#   'Коновалов Касьян Харитонович',
#   'Лапина Татьяна Святославовна',
#   'Нестеров Милица Степановна',
#   'Захаров Денис Жоресович',
#   'Мельникова Алла Ярославович',
#   'Никифоров Евгений Эльдаровна',
#   'Фомичев Кира Жанович',
#   'Данилов Ферапонт Валерьевич',
#   'Жуков Ульян Владиславович',
#   'Суворова Филипп Евстигнеевич',
#   'Титова Алексей Алексеевна',
#   'Шарапов Гостомысл Тарасович',
#   'Давыдова Фортунат Даниилович',
#   'Новикова Лавр Георгиевич',
#   'Ситников Ладимир Устинович',
#   'Муравьева Ювеналий Артемовна',
#   'Голубева Глафира Борисовна',
#   'Сафонова Филарет Вадимовна',
#   'Кузьмина Твердислав Евстигнеевич',
#   'Сорокин Феоктист Викторовна',
#   'Кириллов Никита Венедиктович',
#   'Калашников Флорентин Вадимовна',
#   'Чернов Натан Владиславович',
#   'Васильев Леон Федосеевич',
#   'Зайцев Маргарита Викторович',
#   'Егорова Раиса Фомич',
#   'Горшкова Регина Харитонович',
#   'Данилова Корнил Тарасович',
#   'Филиппова Кузьма Трифонович',
#   'Шубин Михей Изотович',
#   'Кузьмина Парфен Давыдович',
#   'Рябова Валерий Гавриилович',
#   'Филиппов Жанна Ерофеевич',
#   'Третьяков Ким Матвеевна',
#   'Комиссарова Вячеслав Филимонович'],
#  'regions': ('Могилёвская область',
#   'Гродненская область',
#   'Минская область',
#   'Брестская область',
#   'Минск',
#   'Минская область',
#   'Брестская область',
#   'Витебская область',
#   'Минская область',
#   'Минская область',
#   'Гомельская область',
#   'Брестская область',
#   'Брестская область',
#   'Гродненская область',
#   'Минск',
#   'Брестская область',
#   'Брестская область',
#   'Гродненская область',
#   'Могилёвская область',
#   'Брестская область',
#   'Брестская область',
#   'Могилёвская область',
#   'Могилёвская область',
#   'Минск',
#   'Брестская область',
#   'Гродненская область',
#   'Минск',
#   'Минская область',
#   'Могилёвская область',
#   'Минская область',
#   'Витебская область',
#   'Гомельская область',
#   'Гомельская область',
#   'Витебская область',
#   'Витебская область',
#   'Гомельская область',
#   'Гомельская область',
#   'Минск',
#   'Гомельская область',
#   'Витебская область',
#   'Могилёвская область',
#   'Гродненская область',
#   'Витебская область',
#   'Брестская область',
#   'Гомельская область',
#   'Минск',
#   'Гродненская область',
#   'Гродненская область',
#   'Гомельская область',
#   'Могилёвская область',
#   'Гродненская область',
#   'Витебская область',
#   'Гомельская область',
#   'Минская область',
#   'Могилёвская область',
#   'Гомельская область',
#   'Гомельская область',
#   'Гомельская область',
#   'Могилёвская область',
#   'Могилёвская область',
#   'Минская область',
#   'Минская область',
#   'Минская область',
#   'Гродненская область',
#   'Минск',
#   'Минск',
#   'Минская область',
#   'Витебская область',
#   'Витебская область',
#   'Минская область',
#   'Минская область',
#   'Минск',
#   'Брестская область',
#   'Могилёвская область',
#   'Могилёвская область',
#   'Могилёвская область',
#   'Могилёвская область',
#   'Минск',
#   'Минская область',
#   'Брестская область',
#   'Минская область',
#   'Витебская область',
#   'Могилёвская область',
#   'Минск',
#   'Минск',
#   'Брестская область',
#   'Брестская область',
#   'Витебская область',
#   'Гродненская область',
#   'Гродненская область',
#   'Минск',
#   'Гомельская область',
#   'Гродненская область',
#   'Гомельская область',
#   'Брестская область',
#   'Минск',
#   'Гомельская область',
#   'Гомельская область',
#   'Минск',
#   'Могилёвская область'),
#  'cities': ('Осиповичи',
#   'Лида',
#   'Слуцк',
#   'Берёза',
#   'Минск',
#   'Молодечно',
#   'Берёза',
#   'Орша',
#   'Борисов',
#   'Слуцк',
#   'Жлобин',
#   'Брест',
#   'Берёза',
#   'Слоним',
#   'Минск',
#   'Барановичи',
#   'Барановичи',
#   'Волковыск',
#   'Осиповичи',
#   'Брест',
#   'Берёза',
#   'Могилёв',
#   'Горки',
#   'Минск',
#   'Берёза',
#   'Волковыск',
#   'Минск',
#   'Борисов',
#   'Бобруйск',
#   'Слуцк',
#   'Полоцк',
#   'Жлобин',
#   'Речица',
#   'Витебск',
#   'Орша',
#   'Речица',
#   'Речица',
#   'Минск',
#   'Жлобин',
#   'Орша',
#   'Бобруйск',
#   'Гродно',
#   'Новополоцк',
#   'Пинск',
#   'Речица',
#   'Минск',
#   'Слоним',
#   'Лида',
#   'Жлобин',
#   'Бобруйск',
#   'Слоним',
#   'Орша',
#   'Жлобин',
#   'Слуцк',
#   'Бобруйск',
#   'Речица',
#   'Речица',
#   'Гомель',
#   'Бобруйск',
#   'Бобруйск',
#   'Молодечно',
#   'Слуцк',
#   'Борисов',
#   'Слоним',
#   'Минск',
#   'Минск',
#   'Слуцк',
#   'Новополоцк',
#   'Новополоцк',
#   'Борисов',
#   'Слуцк',
#   'Минск',
#   'Пинск',
#   'Осиповичи',
#   'Осиповичи',
#   'Осиповичи',
#   'Могилёв',
#   'Минск',
#   'Молодечно',
#   'Барановичи',
#   'Жодино',
#   'Витебск',
#   'Осиповичи',
#   'Минск',
#   'Минск',
#   'Брест',
#   'Берёза',
#   'Полоцк',
#   'Слоним',
#   'Волковыск',
#   'Минск',
#   'Гомель',
#   'Гродно',
#   'Речица',
#   'Брест',
#   'Минск',
#   'Жлобин',
#   'Речица',
#   'Минск',
#   'Осиповичи')}

# %%
# -----------------------
# НАСТРОЙКА И ГЕНЕРАЦИЯ ДАТЫ
# -----------------------

# Количество создаваемых дат
NUM_DATES = 5000

# Начальные и конечные метки дат
start_date = datetime.datetime(2024, 4, 1, 9, 0, 0)
end_date = datetime.datetime(2025, 3, 31, 18, 0, 0)

# Функция для генерации случайной даты (только будни, с 9 до 18)
def generate_random_datetime(start, end):
    while True:
        # Случайное число секунд между start и end
        total_seconds = int((end - start).total_seconds())
        rand_second = random.randint(0, total_seconds)
        dt = start + datetime.timedelta(seconds=rand_second)

        # Проверяем, что это будний день (Mon-Fri)
        if dt.weekday() < 5:  # 0-понедельник, 4-пятница
            # Проверяем время с 9:00 до 18:00
            if 9 <= dt.hour < 18:
                return dt.strftime("%Y-%m-%d %H:%M:%S")
            
DATE_REQUEST = [generate_random_datetime(start_date, end_date) for _ in range(NUM_DATES)]


# Сортируем список дат по возрастанию
DATE_REQUEST.sort()

DATE_REQUEST
# Out:
# ['2024-04-01 09:19:58',
#  '2024-04-01 09:47:51',
#  '2024-04-01 09:51:38',
#  '2024-04-01 10:34:54',
#  '2024-04-01 10:43:05',
#  '2024-04-01 10:49:24',
#  '2024-04-01 11:18:03',
#  '2024-04-01 11:40:39',
#  '2024-04-01 12:17:45',
#  '2024-04-01 13:36:53',
#  '2024-04-01 13:59:42',
#  '2024-04-01 14:03:37',
#  '2024-04-01 14:58:52',
#  '2024-04-01 15:18:00',
#  '2024-04-01 15:22:14',
#  '2024-04-01 15:42:33',
#  '2024-04-01 15:43:33',
#  '2024-04-01 16:51:33',
#  '2024-04-01 16:51:36',
#  '2024-04-29 09:12:42',
#  '2024-04-29 11:41:10',
#  '2024-04-29 13:02:36',
#  '2024-04-29 13:34:57',
#  '2024-04-29 14:03:25',
#  '2024-04-29 16:17:53',
#  '2024-04-29 16:18:23',
#  '2024-04-29 16:34:41',
#  '2024-04-29 16:35:17',
#  '2024-04-29 16:39:32',
#  '2024-04-29 17:12:38',
#  '2024-04-29 17:19:59',
#  '2024-04-29 17:32:47',
#  '2024-04-29 17:38:58',
#  '2024-04-29 17:55:03',
#  '2024-04-29 17:55:39',
#  '2024-04-30 09:08:14',
#  '2024-04-30 09:58:23',
#  '2024-04-30 10:24:43',
#  '2024-04-30 10:28:14',
#  '2024-04-30 10:47:40',
#  '2024-04-30 10:50:36',
#  '2024-04-30 10:55:42',
#  '2024-04-30 11:54:56',
#  '2024-04-30 11:55:52',
#  '2024-04-30 12:02:04',
#  '2024-04-30 12:04:23',
#  '2024-04-30 12:26:37',
#  '2024-04-30 12:30:00',
#  '2024-04-30 13:11:28',
#  '2024-04-30 13:23:47',
#  '2024-04-30 15:02:39',
#  '2024-04-30 15:46:42',
#  '2024-04-30 16:51:45',
#  '2024-04-30 17:12:03',
#  '2024-05-01 09:12:18',
#  '2024-05-01 09:35:41',
#  '2024-05-01 10:14:49',
#  '2024-05-01 10:53:18',
#  '2024-05-01 11:07:47',
#  '2024-05-01 11:09:28',
#  '2024-05-01 11:23:37',
#  '2024-05-01 11:34:04',
#  '2024-05-01 11:34:53',
#  '2024-05-01 12:08:50',
#  '2024-05-01 13:32:43',
#  '2024-05-01 14:01:52',
#  '2024-05-01 14:12:37',
#  '2024-05-01 14:13:42',
#  '2024-05-01 14:13:47',
#  '2024-05-01 14:29:52',
#  '2024-05-01 14:57:36',
#  '2024-05-01 15:01:42',
#  '2024-05-01 15:24:37',
#  '2024-05-01 15:26:29',
#  '2024-05-01 16:10:07',
#  '2024-05-01 16:41:24',
#  '2024-05-01 16:46:34',
#  '2024-05-01 17:21:11',
#  '2024-05-01 17:29:41',
#  '2024-05-01 17:32:45',
#  '2024-05-01 17:52:25',
#  '2024-05-02 10:15:05',
#  '2024-05-02 10:44:20',
#  '2024-05-02 10:48:10',
#  '2024-05-02 11:01:27',
#  '2024-05-02 11:14:32',
#  '2024-05-02 11:15:26',
#  '2024-05-02 11:32:07',
#  '2024-05-02 12:14:32',
#  '2024-05-02 12:44:00',
#  '2024-05-02 13:54:02',
#  '2024-05-02 14:09:06',
#  '2024-05-02 14:54:41',
#  '2024-05-02 15:22:06',
#  '2024-05-02 16:11:08',
#  '2024-05-02 17:20:44',
#  '2024-05-02 17:23:21',
#  '2024-05-03 09:11:46',
#  '2024-05-03 09:12:54',
#  '2024-05-03 09:16:58',
#  '2024-05-03 10:03:01',
#  '2024-05-03 10:22:34',
#  '2024-05-03 10:24:32',
#  '2024-05-03 11:01:35',
#  '2024-05-03 11:13:57',
#  '2024-05-03 11:15:54',
#  '2024-05-03 11:32:45',
#  '2024-05-03 12:41:54',
#  '2024-05-28 14:33:49',
#  '2024-05-28 14:37:34',
#  '2024-05-28 14:38:55',
#  '2024-05-28 14:57:07',
#  '2024-05-28 15:06:14',
#  '2024-05-28 15:18:42',
#  '2024-05-28 15:40:28',
#  '2024-05-28 15:42:57',
#  '2024-05-28 15:55:46',
#  '2024-05-28 16:46:57',
#  '2024-05-28 17:27:00',
#  '2024-05-28 17:46:32',
#  '2024-05-29 10:53:20',
#  '2024-05-29 11:00:40',
#  '2024-05-29 11:11:12',
#  '2024-05-29 11:46:03',
#  '2024-05-29 12:27:56',
#  '2024-05-29 14:26:32',
#  '2024-05-29 14:44:58',
#  '2024-05-29 15:41:27',
#  '2024-05-29 15:47:50',
#  '2024-05-29 15:53:25',
#  '2024-05-29 15:55:35',
#  '2024-05-29 15:56:15',
#  '2024-05-29 16:50:28',
#  '2024-05-29 17:09:07',
#  '2024-05-29 17:13:26',
#  '2024-05-29 17:20:31',
#  '2024-05-30 09:20:32',
#  '2024-05-30 10:13:07',
#  '2024-05-30 11:08:03',
#  '2024-05-30 11:39:22',
#  '2024-05-30 12:07:56',
#  '2024-05-30 12:58:04',
#  '2024-05-30 13:25:26',
#  '2024-05-30 13:29:02',
#  '2024-05-30 13:40:27',
#  '2024-05-30 13:40:41',
#  '2024-05-30 14:21:47',
#  '2024-05-30 15:22:46',
#  '2024-05-30 16:05:05',
#  '2024-05-30 16:17:16',
#  '2024-05-30 16:36:31',
#  '2024-05-30 16:43:31',
#  '2024-05-30 17:11:13',
#  '2024-05-31 09:10:06',
#  '2024-05-31 09:33:22',
#  '2024-05-31 09:37:27',
#  '2024-05-31 09:57:16',
#  '2024-05-31 10:38:23',
#  '2024-05-31 11:02:46',
#  '2024-05-31 11:08:11',
#  '2024-05-31 11:36:43',
#  '2024-05-31 11:38:27',
#  '2024-05-31 11:53:37',
#  '2024-05-31 13:37:46',
#  '2024-05-31 13:48:53',
#  '2024-05-31 13:56:31',
#  '2024-05-31 14:02:58',
#  '2024-05-31 14:21:15',
#  '2024-05-31 16:15:43',
#  '2024-05-31 17:13:11',
#  '2024-05-31 17:18:18',
#  '2024-05-31 17:31:52',
#  '2024-06-03 09:33:32',
#  '2024-06-03 10:19:37',
#  '2024-06-03 10:25:57',
#  '2024-06-03 12:03:54',
#  '2024-06-03 12:31:10',
#  '2024-06-03 12:36:19',
#  '2024-06-03 13:04:06',
#  '2024-06-03 13:04:27',
#  '2024-06-03 13:53:57',
#  '2024-06-03 14:02:12',
#  '2024-06-03 14:48:16',
#  '2024-06-03 14:50:46',
#  '2024-06-03 15:10:46',
#  '2024-06-03 15:24:25',
#  '2024-06-03 15:30:42',
#  '2024-06-03 15:43:02',
#  '2024-06-03 16:32:30',
#  '2024-06-03 17:29:23',
#  '2024-06-03 17:36:59',
#  '2024-06-04 09:13:07',
#  '2024-06-04 09:16:27',
#  '2024-06-04 09:24:42',
#  '2024-06-04 09:49:32',
#  '2024-06-04 10:45:38',
#  '2024-06-04 10:53:07',
#  '2024-06-04 10:58:06',
#  '2024-06-04 11:57:57',
#  '2024-06-04 14:05:59',
#  '2024-06-04 14:40:33',
#  '2024-06-04 15:44:29',
#  '2024-06-04 15:48:20',
#  '2024-06-04 16:26:03',
#  '2024-06-04 16:33:29',
#  '2024-06-04 16:38:29',
#  '2024-06-04 16:50:05',
#  '2024-06-04 16:59:56',
#  '2024-06-05 09:06:37',
#  '2024-06-05 09:13:57',
#  '2024-06-05 09:35:37',
#  '2024-06-05 10:17:21',
#  '2024-06-05 10:55:01',
#  '2024-06-05 11:08:56',
#  '2024-06-05 12:16:46',
#  '2024-06-05 12:41:34',
#  '2024-06-05 13:46:54',
#  '2024-06-05 13:49:26',
#  '2024-06-05 14:46:22',
#  '2024-06-05 15:20:50',
#  '2024-06-05 15:21:57',
#  '2024-06-05 15:47:59',
#  '2024-06-05 16:19:38',
#  '2024-06-05 16:37:43',
#  '2024-06-05 16:49:16',
#  '2024-06-05 16:57:04',
#  '2024-06-05 17:37:23',
#  '2024-06-06 09:23:25',
#  '2024-06-06 09:38:23',
#  '2024-06-06 10:29:43',
#  '2024-06-06 10:39:36',
#  '2024-06-06 11:17:57',
#  '2024-06-06 11:40:57',
#  '2024-06-06 12:29:39',
#  '2024-06-06 12:40:15',
#  '2024-06-06 13:20:14',
#  '2024-06-06 13:20:35',
#  '2024-06-06 13:33:02',
#  '2024-06-06 13:56:19',
#  '2024-06-06 13:57:42',
#  '2024-06-06 14:01:32',
#  '2024-06-06 14:17:22',
#  '2024-06-06 14:47:51',
#  '2024-06-06 15:00:20',
#  '2024-06-06 15:10:54',
#  '2024-06-06 15:25:35',
#  '2024-06-06 15:56:25',
#  '2024-06-06 16:14:42',
#  '2024-06-06 16:16:24',
#  '2024-06-06 16:28:52',
#  '2024-06-06 16:44:34',
#  '2024-06-06 16:59:08',
#  '2024-06-06 17:16:17',
#  '2024-06-06 17:45:48',
#  '2024-06-07 09:04:22',
#  '2024-06-07 09:36:39',
#  '2024-06-07 11:20:09',
#  '2024-06-07 11:40:47',
#  '2024-06-07 12:20:55',
#  '2024-06-07 12:34:04',
#  '2024-06-07 13:05:58',
#  '2024-06-07 13:10:50',
#  '2024-06-07 14:16:24',
#  '2024-06-07 15:20:49',
#  '2024-06-07 15:39:55',
#  '2024-06-07 16:11:24',
#  '2024-06-07 16:17:29',
#  '2024-06-07 17:17:57',
#  '2024-06-07 17:38:57',
#  '2024-06-07 17:56:30',
#  '2024-06-10 09:16:10',
#  '2024-06-10 10:02:48',
#  '2024-06-10 10:10:08',
#  '2024-06-10 10:12:45',
#  '2024-06-10 10:25:03',
#  '2024-06-10 10:30:42',
#  '2024-06-10 11:27:23',
#  '2024-06-10 12:01:25',
#  '2024-06-10 12:15:11',
#  '2024-06-10 12:19:18',
#  '2024-06-10 12:34:19',
#  '2024-06-10 12:49:34',
#  '2024-06-10 12:54:43',
#  ...]

# %%
# -----------------------
# НАСТРОЙКА И ГЕНЕРАЦИЯ ОСНОВНОГО НАБОРА ЗАКАЗОВ
# -----------------------

# Количество создаваемых строк равно количеству дат 
NUM_ROWS = NUM_DATES

# Начальное и конечное количество в заказ
MIN_QTY, MAX_QTY = 1, 200

# Установка скидок в зависимости от количества в продажу
DISCOUNT_RANGE = {
            range(1, 10): 0.0,
            range(10, 50): 0.1,
            range(50, 100): 0.2,
            range(100, 201): 0.25
}

# Открываем файл CSV на запись
with open(csv_file, 'w', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    
    # Запишем заголовки
    writer.writerow([
        "OrderID", "Product", "ProductCategory", "Brand", "Description", "StandardCost", 
        "UnitPrice", "DateRequest", "QuantitySold", "DiscountPrice", "TotalPrice", 
        "CustomerName", "CustomerRegion", "CustomerCity", "Canceled", "Feedback"
    ])
    
    for order_id in range(1, NUM_ROWS + 1):
        # 1. OrderID
        order_id_val = order_id + 4838

        # 2. Product
        product_val = random.choice(PRODUCTS_INFO["products"])

        # Получение индекса со словаря по значению Product
        product_idx = next((i for i, val in enumerate(PRODUCTS_INFO["products"]) if val == product_val))

        # 3. ProductCategory
        cat_val = PRODUCTS_INFO["categories"][product_idx]

        # 4. Brand (иногда Unknown)
        brand_val = PRODUCTS_INFO["brands"][product_idx]
        if brand_val is None:
            brand_val = "Unknown"

        # 5. Description (иногда None)
        descr_val = PRODUCTS_INFO["descriptions"][product_idx]
        if descr_val is None:
            descr_val = ""

        # 6. StandardCost
        st_cost = PRODUCTS_INFO["standard_costs"][product_idx]

        # 7. UnitPrice
        unit_price = PRODUCTS_INFO["unit_prices"][product_idx]
        
        # 8. DateRequest
        date_req = DATE_REQUEST[order_id - 1]
        
        # 9. QuantitySold
        quantity_sold = random.randint(MIN_QTY, MAX_QTY)

        # 10. DiscountPrice
        discount_price = next((value for key, value in DISCOUNT_RANGE.items() if quantity_sold in key))

        # 11. TotalPrice
        total_price = round(quantity_sold * unit_price * (1 + discount_price), 2)
        
        # 12. CustomerName
        customer_name = random.choice(CUSTOMERS_INFO["names"])

        # Получение индекса со словаря по значению CustomerName
        customer_idx = next((i for i, val in enumerate(CUSTOMERS_INFO["names"]) if val == customer_name))

        # 13. CustomerRegion
        region_val = CUSTOMERS_INFO["regions"][customer_idx]

        # 14. CustomerCity
        city_val = CUSTOMERS_INFO["cities"][customer_idx]

        # 15. Canceled (бит) - примерно 10% отмены заказа
        canceled_val = 1 if random.random() < 0.1 else 0

        # Если отмена, то продажа 0
        total_price = 0 if canceled_val == 1 else total_price

        # 16. Feedback - 1..5 или 20% None
        if random.random() < 0.2:
            feedback_val = None
        else:
            feedback_val = random.randint(1, 5)
        
        # Запись строки в CSV
        writer.writerow([
            order_id_val,
            product_val,
            cat_val,
            brand_val,
            descr_val,
            st_cost,
            unit_price,
            date_req,
            quantity_sold,
            discount_price,
            total_price,
            customer_name,
            region_val,
            city_val,
            canceled_val,
            feedback_val
        ])

print("Файл electronics_retail_dataset.csv успешно сгенерирован!")
# Out:
# Файл electronics_retail_dataset.csv успешно сгенерирован!
